# %% [markdown]
# ### This analysis was done in excel. I mentioned it in python as a more appropriate tool.
#
# link of excercise:
# https://www.coursera.org/learn/big-data-management/supplement/SBtIc/exploring-the-relational-data-model-of-comma-separated-values-csv

# %%
import pandas as pd

# %%
df = pd.read_csv('census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2875 entries, 0 to 2874
# Data columns (total 100 columns):
# SUMLEV                   2875 non-null int64
# REGION                   2875 non-null int64
# DIVISION                 2875 non-null int64
# STATE                    2875 non-null int64
# COUNTY                   2875 non-null int64
# STNAME                   2875 non-null object
# CTYNAME                  2875 non-null object
# CENSUS2010POP            2875 non-null int64
# ESTIMATESBASE2010        2875 non-null int64
# POPESTIMATE2010          2875 non-null int64
# POPESTIMATE2011          2875 non-null int64
# POPESTIMATE2012          2875 non-null int64
# POPESTIMATE2013          2875 non-null int64
# POPESTIMATE2014          2875 non-null int64
# POPESTIMATE2015          2875 non-null int64
# NPOPCHG_2010             2875 non-null int64
# NPOPCHG_2011             2875 non-null int64
# NPOPCHG_2012             2875 non-null int64
# ...

# %%
df['STNAME'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia'], dtype=object)

# %% [markdown]
# ### Filter STNAME is 'Californa' and CENSUS2010POP is greater than 1000000

# %%
df[(df['STNAME'] == 'California') & (df['CENSUS2010POP'] > 1000000)]
# Out:
#      SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME  \
# 190      40       4         9      6       0  California
# 191      50       4         9      6       1  California
# 197      50       4         9      6      13  California
# 209      50       4         9      6      37  California
# 220      50       4         9      6      59  California
# 223      50       4         9      6      65  California
# 224      50       4         9      6      67  California
# 226      50       4         9      6      71  California
# 227      50       4         9      6      73  California
# 233      50       4         9      6      85  California
#
#                    CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 190             California       37253956           37254503         37334079
# 191         Alameda County        1510271            1510261          1513754
# 197    Contra Costa County        1049025            1049197          1052921
# ...

# %% [markdown]
# ### mena of CENSUS2010POP from some rows

# %%
df.loc[3:11]['CENSUS2010POP'].mean()
# Out:
# 40219.333333333336

# %%
df.loc[14:23]['CENSUS2010POP'].sum()
# Out:
# 340375
